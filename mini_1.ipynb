# %%
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input,decode_predictions
from keras.preprocessing.image import image

model = InceptionV3(include_top = True,weights = 'imagenet',input_shape = (299,299,3))
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0827 22:01:33.464928  1856 deprecation_wrapper.py:119] From c:\users\clive\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0827 22:01:33.766139  1856 deprecation_wrapper.py:119] From c:\users\clive\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0827 22:01:33.846696  1856 deprecation_wrapper.py:119] From c:\users\clive\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
model.get_input_shape_at(0)
# Out:
# (None, 299, 299, 3)

# %%
import os
path = 'C:\\Users\USERNAME\Downloads'
lt = [i for i in os.listdir(path) if i.split('.')[-1].lower() in ['png','jpg','jpeg']]
lt
# Out:
# ['2064544-gp.jpg',
#  'bee.jpg',
#  'bee2.jpg',
#  'download (1).jpg',
#  'download (2).jpg',
#  'download (3).jpg',
#  'download (4).jpg',
#  'download (5).jpg',
#  'download.jpg',
#  'download.png',
#  'IMG_4589.jpg',
#  'peacock.jpg',
#  'rhinoceros_beetle.jpg']

# %%
i = 2
images = []
for i in lt:
    img = image.load_img(os.path.join(path,i), target_size=(299, 299))
    x = image.img_to_array(img)
#     x = np.expand_dims(x, axis = 0)
    x = preprocess_input(x)
    images.append(x)

# %%
np.array(images).shape
# Out:
# (13, 299, 299, 3)

# %%
features = model.predict(np.array(images))
op = np.squeeze(np.array(decode_predictions(features, top = 1)))
    
# plt.imshow(image.load_img(os.path.join(path,i)))
# plt.show()

op
# Out:
# array([['n04355933', 'sunglass', '0.09520177'],
#        ['n02206856', 'bee', '0.94195294'],
#        ['n02206856', 'bee', '0.76615113'],
#        ['n09468604', 'valley', '0.7555045'],
#        ['n04366367', 'suspension_bridge', '0.797347'],
#        ['n03476684', 'hair_slide', '0.38071224'],
#        ['n09332890', 'lakeside', '0.53589755'],
#        ['n03314780', 'face_powder', '0.26464468'],
#        ['n07714571', 'head_cabbage', '0.7935195'],
#        ['n07892512', 'red_wine', '0.25759616'],
#        ['n03832673', 'notebook', '0.08100602'],
#        ['n01806143', 'peacock', '0.97545004'],
#        ['n02174001', 'rhinoceros_beetle', '0.9064053']], dtype='<U17')

# %%
a = 'apple'

a.replace('p','b')
# Out:
# 'abble'

# %%
name = input('enter name')
# import re
for j,i in enumerate(op):
    
    
    if name in i[1].replace('_',' '):
        plt.figure()
        plt.imshow(cv2.imread(os.path.join(path,lt[j])))
# Out:
# enter namepeacock

# %%
# Out:
# 1
# 2
